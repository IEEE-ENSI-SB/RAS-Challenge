# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.0/654.0 kB 5.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)
#
# OS                  Linux-5.15.120+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.68 GB
# CPU                 Intel Xeon 2.30GHz
# CUDA                11.8
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.23.5>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.1.0+cu118>=1.8.0
# torchvision         ✅ 0.16.0+cu118>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.12.2>=0.11.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/tired/data.yaml epochs=5 imgsz=640
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train5/confusion_matrix.png', width=600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train5/weights/best.pt data=/content/drive/MyDrive/tired/data.yaml
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/11DcBZ5ERsyiXX7ueqhLH5WgImX-X_H3Y/tired/valid/labels.cache... 150 images, 0 backgrounds, 0 corrupt: 100% 150/150 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:06<00:00,  1.57it/s]
#                    all        150        166      0.912      0.782      0.882      0.565
#                  tired        150         50          1      0.604      0.867      0.456
#                 normal        150         58      0.966      0.828       0.94      0.662
#                  drunk        150         58      0.771      0.914      0.839      0.578
# Speed: 1.6ms preprocess, 24.1ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to runs/detect/val3
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train5/weights/best.pt conf=0.5 source=/content/drive/MyDrive/tired/test/images save_txt=true save_conf=true
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/250 /content/drive/MyDrive/tired/test/images/Drunkface307B3_jpg.rf.381426984740c683729f9df93ba9044a.jpg: 448x640 2 drunks, 212.3ms
# image 2/250 /content/drive/MyDrive/tired/test/images/Drunkface308B1_jpg.rf.c7f2b7ebbfd0ad169f4ebe4e280a3deb.jpg: 448x640 4 drunks, 27.7ms
# image 3/250 /content/drive/MyDrive/tired/test/images/Drunkface308B2_jpg.rf.0563d5c39ddf61c32bd7a7ed18390252.jpg: 448x640 4 drunks, 35.2ms
# image 4/250 /content/drive/MyDrive/tired/test/images/Drunkface308B3_jpg.rf.9ce6cf52b45ada8eda846f49caf50c0c.jpg: 448x640 2 drunks, 27.9ms
# image 5/250 /content/drive/MyDrive/tired/test/images/Drunkface308B_jpg.rf.e47617694c9201fdc4d79864a285dff5.jpg: 448x640 4 drunks, 27.7ms
# ...
